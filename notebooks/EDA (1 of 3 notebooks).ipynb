# %% [markdown]
# # Dene Stalk

# %% [markdown]
# #### NLP soft weighted voting ensemble multi-class classifier to predict spend categories using Government of California’s purchase order data

# %% [markdown]
# BrianStation Data Science Diploma Capstone, March 2020

# %%
# Import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# The data set used was the [Goverment of California's 2012-2015 Purchase Orders ](https://data.ca.gov/dataset/purchase-order-data/resource/bb82edc5-9c78-44e2-8947-68ece26197c5) that are mapped the United Nations Standard Products & Services Code (UNSPSC). A Group Title column was added using excel (vlookup) for Goods and Services based on Segment Title.

# %% [markdown]
# <img src="UNSPSC.PNG"
#      style="float: left; margin-right: 10px;" />

# %%
df_original = pd.read_csv('https://data.ca.gov/dataset/ae343670-f827-4bc8-9d44-2af937d60190/resource/bb82edc5-9c78-44e2-8947-68ece26197c5/download/purchase-order-data-2012-2015-.csv')
df = df_original.copy()

# %% [markdown]
# ## Initial Exploration

# %% [markdown]
# The dataset is made up of 344,504 rows (line items) with 32 columns comprised of 9 float and 23 object data types. The dataset has numerous columns specific to the Government of California (e.g. Acquisition Method), however the goal of this project is to develop a model that is transferable to other organizations and are disgarded.

# %%
# check dataset shape
df.shape
# Out:
# (344504, 32)

# %%
# peak into the dataset
df.sample(5)
# Out:
#        Creation Date Purchase Date Fiscal Year LPA Number  \
# 333189     5/22/2014     5/22/2014   2013-2014        NaN
# 158155    12/30/2014    12/24/2014   2014-2015        NaN
# 233800    12/10/2012    12/10/2012   2012-2013        NaN
# 296113     5/22/2013      2/4/2013   2012-2013        NaN
# 58984      7/26/2013     11/2/2010   2013-2014        NaN
#
#        Purchase Order Number Requisition Number Acquisition Type  \
# 333189              C0000416                NaN     NON-IT Goods
# 158155            4500218500                NaN     NON-IT Goods
# 233800            4500162549                NaN     NON-IT Goods
# 296113               AF54738                NaN     NON-IT Goods
# 58984               CFF 7228                NaN  NON-IT Services
#
#        Sub-Acquisition Type                           Acquisition Method  \
# 333189                  NaN                           Formal Competitive
# 158155                  NaN                         Informal Competitive
# 233800                  NaN  Services are specifically exempt by statute
# 296113                  NaN                         Informal Competitive
# 58984     Personal Services                           Formal Competitive
#
#        Sub-Acquisition Method  ... Normalized UNSPSC  \
# 333189                    NaN  ...        45111602.0
# 158155                    NaN  ...        27113201.0
# 233800                    NaN  ...        50131606.0
# 296113                    NaN  ...        23301501.0
# 58984                     NaN  ...        55101515.0
#
#                                           Commodity Title       Class  \
# 333189                                   Projection lamps  45111600.0
# 158155                                  General tool kits  27113200.0
# 233800                                         Fresh eggs  50131600.0
# 296113  Wire and cable cutting and terminal assembly e...  23301500.0
# 58984              Promotional material or annual reports  55101500.0
#
#                                               Class Title      Family  \
# 333189                            Projectors and supplies  45110000.0
# 158155                                          Tool kits  27110000.0
# 233800                           Eggs and egg substitutes  50130000.0
# 296113  Wire working machinery and equipment and acces...  23300000.0
# 58984                                Printed publications  55100000.0
#
#                                              Family Title     Segment  \
# 333189  Audio and visual presentation and composing eq...  45000000.0
# 158155                                         Hand tools  27000000.0
# 233800                            Dairy products and eggs  50000000.0
# 296113                       Wire machinery and equipment  23000000.0
# 58984                                       Printed media  55000000.0
#
#                                             Segment Title  \
# 333189  Printing and Photographic and Audio and Visual...
# 158155                        Tools and General Machinery
# 233800                 Food Beverage and Tobacco Products
# 296113  Industrial Manufacturing and Processing Machin...
# 58984                                  Published Products
#
#                                Location REMOVE AMERISOURCE
# 333189  92105\n(32.738754, -117.094021)                NaN
# 158155  95691\n(38.575311, -121.560401)                NaN
# 233800   73529\n(34.361458, -97.971748)                NaN
# 296113   91609\n(34.16581, -118.378967)                NaN
# 58984   90301\n(33.956998, -118.358491)                NaN
#
# [5 rows x 32 columns]

# %% [markdown]
# There are five main themes of the columns in the original dataset. However only Item Name, Item Description and Supplier Name were used as features with Segment Title as the target. Quantity and Unit Price and Total Price were also in the final dataset but not incorporated in the modelling process, however are used in interpreting the financial impact of the predictions. Below are some of the columns.
#
# Dates:
# + Creation Date
# - Purchase Date
# - Fiscal Year
#
# Internal Information:
# * Department
# * Acquisition Type
# * Acquisition Method
#
# Supplier Information:
# * **Supplier Name**
# * Qualifications
# * Location
#
# Purchase Information:
# * PO number
# * *Quantity*
# * *Unit price*
# * *Total price*
# * **Item Name**
# * **Item Description**
#
# UNSPSC:
# * **Segment Title** and corresponding code
# * Family Title and corresponding code
# * Class Title and corresponding code
# * Commodity Title and corresponding code

# %%
# explore object columns
df.describe(include=['object']).transpose()
# Out:
#                           count  unique  \
# Creation Date            344504    1015
# Purchase Date            327083    2266
# Fiscal Year              344504       3
# LPA Number                90897    1418
# Purchase Order Number    344504  197000
# Requisition Number        14366    5996
# Acquisition Type         344504       5
# Sub-Acquisition Type      68334      25
# Acquisition Method       344504      20
# Sub-Acquisition Method    30883      16
# Department Name          344504     111
# Supplier Name            344468   24728
# Supplier Qualifications  141745     278
# Supplier Zip Code        274424    3993
# CalCard                  344504       2
# Item Name                344473  179659
# Item Description         344305  218697
# Unit Price               344474  126981
# Total Price              344474  149090
# Classification Codes     343487   45743
# Commodity Title          341211   13072
# Class Title              341211    2344
# Family Title             341211     411
# Segment Title            341211      56
# Location                 274424    3993
#
#                                                                        top  \
# Creation Date                                                    6/27/2014
# Purchase Date                                                     7/1/2014
# Fiscal Year                                                      2013-2014
# LPA Number                                                      7-11-51-02
# Purchase Order Number                                           4500211314
# Requisition Number                                              REQ0008872
# Acquisition Type                                              NON-IT Goods
# Sub-Acquisition Type                                     Personal Services
# Acquisition Method                                    Informal Competitive
# Sub-Acquisition Method                                               Fleet
# Department Name              Corrections and Rehabilitation, Department of
# Supplier Name                                    Voyager Fleet Systems Inc
# Supplier Qualifications                                        CA-MB CA-SB
# Supplier Zip Code                                                    95691
# CalCard                                                                 NO
# Item Name                                                 Medical Supplies
# Item Description                                              confidential
# Unit Price                                                          $0.00
# Total Price                                                         $0.00
# Classification Codes                                              15101506
# Commodity Title                                         Gasoline or Petrol
# Class Title                                      Petroleum and distillates
# Family Title             Office machines and their supplies and accesso...
# Segment Title            Information Technology Broadcasting and Teleco...
# Location                                   95691\n(38.575311, -121.560401)
#
#                            freq
# Creation Date              1531
# Purchase Date              4433
# Fiscal Year              120158
# LPA Number                 9267
# Purchase Order Number       602
# Requisition Number          123
# Acquisition Type         213578
# Sub-Acquisition Type      16104
# Acquisition Method        82046
# Sub-Acquisition Method    14148
# Department Name           57533
# Supplier Name             13756
# Supplier Qualifications   53077
# Supplier Zip Code         11095
# CalCard                  339132
# Item Name                  2911
# Item Description           1637
# Unit Price                 7544
# Total Price                7511
# Classification Codes      12679
# Commodity Title           12776
# Class Title               14584
# Family Title              16478
# Segment Title             32679
# Location                  11095

# %%
# explore numeric columns
df.describe().T
# Out:
#                        count          mean           std           min  \
# Supplier Code       344468.0  8.426214e+05  2.466547e+06  0.000000e+00
# Quantity            344474.0  1.945776e+03  9.819831e+04  1.000000e-04
# Normalized UNSPSC   343487.0  4.926200e+07  2.248214e+07  3.018170e+05
# Class               341211.0  4.921572e+07  2.247339e+07  1.010150e+07
# Family              341211.0  4.921157e+07  2.247664e+07  3.018000e+06
# Segment             341211.0  4.907212e+07  2.247862e+07  1.000000e+07
# REMOVE AMERISOURCE       0.0           NaN           NaN           NaN
#
#                            25%         50%         75%          max
# Supplier Code          26819.0   1012554.0   1493440.0  954831781.0
# Quantity                   1.0         1.0         6.0   20000000.0
# Normalized UNSPSC   39111610.0  44121506.0  71151106.0   95141903.0
# Class               39111500.0  44121500.0  71151000.0   95141900.0
# Family              39110000.0  44120000.0  71150000.0   95140000.0
# Segment             39000000.0  44000000.0  71000000.0   95000000.0
# REMOVE AMERISOURCE         NaN         NaN         NaN          NaN

# %% [markdown]
# Kept only relevant columns to reduce dataset and computational needs for cleaning. While the model only incorporates Supplier Name, Item Name and Item Description as features and Segment as target, kept Quantity, Unit Price and Total price for future analysis and cleaning.

# %%
# only keep relevant columns going forward
df = df[['Quantity', 'Unit Price', 'Total Price', 'Supplier Name', 'Item Name', 'Item Description', 'Segment Title']]

# %% [markdown]
# ## Cleaning Process

# %% [markdown]
# As can be seen in the info below, Unit Price and Total Price are objects. They also contain punctuation (e.g. $) that needs to be removed before being converted to a float.

# %%
# check column data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344504 entries, 0 to 344503
# Data columns (total 7 columns):
# Quantity            344474 non-null float64
# Unit Price          344474 non-null object
# Total Price         344474 non-null object
# Supplier Name       344468 non-null object
# Item Name           344473 non-null object
# Item Description    344305 non-null object
# Segment Title       341211 non-null object
# dtypes: float64(1), object(6)
# memory usage: 18.4+ MB

# %%
# example of formatting 
df[['Unit Price', 'Total Price']].sample(5)
# Out:
#          Unit Price  Total Price
# 256418  $20,727.25   $20,727.25
# 334861   $5,440.00    $5,440.00
# 61932       $68.00      $816.00
# 230572  $29,172.00   $29,172.00
# 68577       $22.00    $1,430.00

# %% [markdown]
# Remove punctuation and blank spaces before converting Unit Price and Total Price to a float. However, the dataset uses the accounting formatting for currency with () around negative values. The below cleaning takes that into account by changing the first parenthesis to a negative sign.

# %%
import string

# create punctuation list
punctuation_list = list(string.punctuation)

# remove negative sign and first paranthesis for allow for correct label of negative amounts
punctuation_list.remove('-')
punctuation_list.remove('(')

# add blank spaces
punctuation_list.append(" ")

punctuation_list = ''.join(punctuation_list)

neg_conversion = str.maketrans('(', '-', punctuation_list)
#tbl = str.maketrans('(', '-', '$)')


df['Total Price'] = df['Total Price'].astype(str).apply(lambda x: x.translate(neg_conversion))
df['Unit Price'] = df['Unit Price'].astype(str).apply(lambda x: x.translate(neg_conversion))

df[['Total Price', 'Unit Price']] = df[['Total Price', 'Unit Price']].astype(float)

# check to ensure changes were applied correctly
print('Total Price dtype after cleaning: ', df['Total Price'].dtype)
print('Unit Price dtype after cleaning: ', df['Unit Price'].dtype)
# Out:
# Total Price dtype after cleaning:  float64
# Unit Price dtype after cleaning:  float64

# %%
df[['Unit Price', 'Total Price']].sum()
# Out:
# Unit Price     1.491027e+13
# Total Price    1.505179e+13
# dtype: float64

# %%
df.describe().T
# Out:
#                 count          mean           std           min       25%  \
# Quantity     344474.0  1.945776e+03  9.819831e+04  1.000000e-04      1.00
# Unit Price   344474.0  4.328418e+07  2.141131e+09 -3.086123e+09   3427.25
# Total Price  344474.0  4.369499e+07  2.141135e+09 -3.086123e+09  30000.00
#
#                   50%         75%           max
# Quantity          1.0        6.00  2.000000e+07
# Unit Price    54000.0  1000054.25  7.337038e+11
# Total Price  352539.0  1461666.50  7.337038e+11

# %% [markdown]
# While the raw dataset was relatively clean, some additional cleaning was required. This included removing rows where:
# * Segment Title was blank
# * Total Price was <= 0. Refunds and interdepartmental reimbursements are out of the scope of this project.
# * Supplier Name was input as 'Unknown' or blank
# * Item Name was blank
# * Item Description was input as 'confidential' or blank

# %% [markdown]
# Below is the count of the number of rows removed based on the above conditions

# %%
print('Count of rows with Segment Title as blank: ', df['Segment Title'].isnull().sum())
print('Count of rows with Total Price less than or equal to $0: ', df['Total Price'].le(0).sum())
print('Count of rows with Supplier Name as "Unknown": ', (df['Supplier Name'] == 'Unknown').sum())
print('Count of rows with Supplier Name as blank: ', df['Supplier Name'].isnull().sum())
print('Count of rows with Item Name as blank: ', df['Item Name'].isnull().sum())
print('Count of rows with Item Description as "confidential": ', (df['Item Description'] == 'confidential').sum())
print('Count of rows with Item Description as blank: ', df['Item Description'].isnull().sum())
# Out:
# Count of rows with Segment Title as blank:  3293
# Count of rows with Total Price less than or equal to $0:  8949
# Count of rows with Supplier Name as "Unknown":  4473
# Count of rows with Supplier Name as blank:  36
# Count of rows with Item Name as blank:  31
# Count of rows with Item Description as "confidential":  1637
# Count of rows with Item Description as blank:  199

# %%
# only keep rows with Segment Title inputs

df = df[df['Segment Title'].notna()]

# drop rows with negative or 0 spends
df = df.drop(df[df['Total Price'] <= 0].index)

# drop suppliers listed as 'unknown'
df = df.drop(df[df['Supplier Name'] == 'Unknown'].index)

# drop rows with supplier name missing
df = df.drop(df[df['Supplier Name'].isna() == True].index)

# drop rows with item name missing
df = df.drop(df[df['Item Name'].isna() == True].index)

# drop rows with item description as 'confidential'
df = df.drop(df[df['Item Description'] == 'confidential'].index)

# drop rows with item description missing
df = df.drop(df[df['Item Description'].isna() == True].index)

# check new df shape
print('New dateframe shape: ', df.shape)
# Out:
# New dateframe shape:  (326308, 7)

# %%
# Change Segment Title to Segment Target
df = df.rename(columns={'Segment Title': 'Segment Target'})

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# Segment Target was reduced from 55 to 26 Segment categories. This was accomplished by the bottom 20% of categories by total rows being grouped into either Other Goods or Other Services based on their commodity type. But first those categories needed to be found. A 47% reduction in spend categories resulting in only aggregating 7% of total spend. This was accomplished through the steps.

# %% [markdown]
# First, a column identifying what categories are Services and which are Goods was created.

# %%
services_keywords_list = ['Services', 'services', 'Clubs']

services_keywords_list = '|'.join(services_keywords_list)

df['Services_dummy'] = pd.np.where(df['Segment Target'].str.contains(services_keywords_list, case=True),1,0)

df.sample(5)
# Out:
#         Quantity  Unit Price  Total Price                   Supplier Name  \
# 271569       6.0     19900.0     119400.0              THE PRIMARY SOURCE
# 99269        1.0   4832469.0    4832469.0  Basalite Concrete Products LLC
# 256077       1.0   4523554.0    4523554.0          MJ INDUSTRIAL SUPPLIES
# 196347       6.0     10168.0      61008.0      Grainger Industrial Supply
# 49710      400.0      3975.0    1590000.0                e Poly Star, Inc
#
#                         Item Name           Item Description  \
# 271569               Printer kits               Printer kits
# 99269                      Cement                     Cement
# 256077               Water Heater                          X
# 196347                 Floor Mats                 Floor Mats
# 49710   33x48 orange plastic bags  33x48 orange plastic bags
#
#                                            Segment Target  Services_dummy
# 271569      Office Equipment and Accessories and Supplies               0
# 99269   Structures and Building and Construction and M...               0
# 256077  Distribution and Conditioning Systems and Equi...               0
# 196347  Defense and Law Enforcement and Security and S...               0
# 49710   Material Handling and Conditioning and Storage...               0

# %% [markdown]
# Create a dataframe to check categories where classified appropriately

# %%
# create dataframe with only unique values
df_services= df[['Segment Target', 'Services_dummy']].drop_duplicates()

# sort table
df_services = df_services.sort_values(['Services_dummy', 'Segment Target'], ascending=[False,True]) 

# display table with a widened columns for Segment
df_services.style.set_properties(subset=['Segment Target'], **{'width': '500px'})
# Out:
# <style  type="text/css" >
#     #T_b3540f02_79dd_11ea_af68_7470fdb83070row0_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row1_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row2_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row3_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row4_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row5_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row6_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row7_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row8_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row9_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row10_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row11_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row12_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row13_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row14_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row15_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row16_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row17_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row18_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row19_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row20_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row21_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row22_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row23_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row24_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row25_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row26_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row27_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row28_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row29_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row30_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row31_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row32_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row33_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row34_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row35_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row36_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row37_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row38_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row39_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row40_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row41_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row42_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row43_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row44_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row45_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row46_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row47_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row48_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row49_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row50_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row51_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row52_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row53_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row54_col0 {
#             width:  500px;
#         }    #T_b3540f02_79dd_11ea_af68_7470fdb83070row55_col0 {
#             width:  500px;
#         }</style><table id="T_b3540f02_79dd_11ea_af68_7470fdb83070" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Segment Target</th>        <th class="col_heading level0 col1" >Services_dummy</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b3540f02_79dd_11ea_af68_7470fdb83070level0_row0" class="row_heading level0 row0" >1788</th>
#                         <td id="T_b3540f02_79dd_11ea_af68_7470fdb83070row0_col0" class="data row0 col0" >Building and Facility Construction and Maintenance Services</td>
#                         <td id="T_b3540f02_79dd_11ea_af68_7470fdb83070row0_col1" class="data row0 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_b3540f02_79dd_11ea_af68_7470fdb83070level0_row1" class="row_heading level0 row1" >37</th>
#                         <td id="T_b3540f02_79dd_11ea_af68_7470fdb83070row1_col0" class="data row1 col0" >Editorial and Design and Graphic and Fine Art Services</td>
#                         <td id="T_b3540f02_79dd_11ea_af68_7470fdb83070row1_col1" class="data row1 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_b3540f02_79dd_11ea_af68_7470fdb83070level0_row2" class="row_heading level0 row2" >895</th>
#                         <td id="T_b3540f02_79dd_11ea_af68_7470fdb83070row2_col0" class="data row2 col0" >Education and Training Services</td>
#                         <td id="T_b3540f02_79dd_11ea_af68_7470fdb83070row2_col1" class="data row2 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_b3540f02_79dd_11ea_af68_7470fdb83070level0_row3" class="row_heading level0 row3" >67</th>
#                         <td id="T_b3540f02_79dd_11ea_af68_7470fdb83070row3_col0" class="data row3 col0" >Engineering and Research and Technology Based Services</td>
#                         <td id="T_b3540f02_79dd_11ea_af68_7470fdb83070row3_col1" class="data row3 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_b3540f02_79dd_11ea_af68_7470fdb83070level0_row4" class="row_heading level0 row4" >878</th>
#                         <td id="T_b3540f02_79dd_11ea_af68_7470fdb83070row4_col0" class="data row4 col0" >Environmental Services</td>
#                         <td id="T_b3540f02_79dd_11ea_af68_7470fdb83070row4_col1" class="data row4 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_b3540f02_79dd_11ea_af68_7470fdb83070level0_row5" class="row_heading level0 row5" >932</th>
#                         <td id="T_b3540f02_79dd_11ea_af68_7470fdb83070row5_col0" class="data row5 col0" >Farming and Fishing and Forestry and Wildlife Contracting Services</td>
#                         <td id="T_b3540f02_79dd_11ea_af68_7470fdb83070row5_col1" class="data row5 col1" >1</

# %% [markdown]
# Create a dataframe to identify the categories in the bottom 20% of line item frequency

# %%
# create a dataframe with Segment, Services Total Price grouped by Segment with sum and count (number of rows) of Total Price 
segment_target_df = pd.DataFrame(df.groupby(['Segment Target','Services_dummy'])['Total Price'].agg(['sum','count']).reset_index())

# sort by count
segment_target_df= segment_target_df.sort_values(by=('count'), ascending = False)

# create a column for cummaltive amount of rows
segment_target_df['cum_sum_count'] = segment_target_df['count'].cumsum()

# create a column for cummaltive percent of rows
segment_target_df['cum_perc_count'] = round(100*segment_target_df['cum_sum_count']/segment_target_df['count'].sum(),1)

# create a column for cummaltive sum of total spend
segment_target_df['cum_sum_sum'] = segment_target_df['sum'].cumsum()

# create a column for cummaltive percent of total spend
segment_target_df['cum_perc_sum'] = round(100*segment_target_df['cum_sum_sum']/segment_target_df['sum'].sum(),1)

# %% [markdown]
# Using a nested where clause for segements with the grouping of bottom 20% of segments into either Other Goods or Other Services based on commmodity type

# %%
# using a nested where clause for segements with the grouping of bottom 20% of segments into either Other Goods or Other Services based on commmodity type
segment_target_df['Reduced Segment Target'] = np.where((segment_target_df['cum_perc_count']>80.5) & (segment_target_df['Services_dummy'] == 1), 'Other Services', \
                                                       np.where((segment_target_df['cum_perc_count']>80.5) & (segment_target_df['Services_dummy'] == 0), 'Other Goods', segment_target_df['Segment Target']))

# %% [markdown]
# Create numeric categories of the final string category names to be used in the modelling portion of this project.

# %%
# factorize reduced segement target for modelling 
segment_target_df['Segment Target Cat'] = segment_target_df['Reduced Segment Target'].factorize()[0]

# convert new column is dtype string instead of integer 
segment_target_df['Segment Target Cat'] = segment_target_df['Segment Target Cat'].astype(str) 


# display table with a widened columns for Segment 
segment_target_df.style.set_properties(subset=['Segment Target', 'Reduced Segment Target'], **{'width': '300px'})
# Out:
# <style  type="text/css" >
#     #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row0_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row0_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row1_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row1_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row2_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row2_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row3_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row3_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row4_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row4_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row5_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row5_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row6_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row6_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row7_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row7_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row8_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row8_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row9_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row9_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row10_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row10_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row11_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row11_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row12_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row12_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row13_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row13_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row14_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row14_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row15_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row15_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row16_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row16_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row17_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row17_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row18_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row18_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row19_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row19_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row20_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row20_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row21_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row21_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row22_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row22_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row23_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row23_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row24_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row24_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row25_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row25_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row26_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row26_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row27_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row27_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row28_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row28_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row29_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row29_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row30_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row30_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row31_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row31_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row32_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row32_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row33_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row33_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row34_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row34_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row35_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row35_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row36_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row36_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row37_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row37_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row38_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row38_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row39_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row39_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row40_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row40_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row41_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row41_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row42_col0 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row42_col8 {
#             width:  300px;
#         }    #T_b37f6e1a_79dd_11ea_9a3f_7470fdb83070row43_col0 {
#             width:  300px;

# %% [markdown]
# Merge cleaned df and newly created segment_target_df

# %%
# left join on Segment Target
df_merged = pd.merge(df,segment_target_df[['Segment Target','Reduced Segment Target', 'Segment Target Cat']], how='left', left_on='Segment Target', right_on ='Segment Target')

# %% [markdown]
# Since the original dataset did not have goods and services, that column was dropped.

# %%
# drop services_dummy and original Segment Target
df_merged = df_merged.drop(['Services_dummy', 'Segment Target'], axis=1)

# %%
# rename reduced segment target to segment target for the modelling portion
df_merged = df_merged.rename(columns={'Reduced Segment Target': 'Segment Target'})

# %% [markdown]
# ## Finalized Cleaned Dataset

# %% [markdown]
# Check to see if there are any nulls, the correct columns are present in the correct data type.
#
# The cleaned dataset has 326,208 rows with 8 columns, 3 float and 5 object.

# %%
print(df_merged.shape)
# Out:
# (326308, 8)

# %%
# check info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 326308 entries, 17 to 344503
# Data columns (total 8 columns):
# Quantity            326308 non-null float64
# Unit Price          326308 non-null float64
# Total Price         326308 non-null float64
# Supplier Name       326308 non-null object
# Item Name           326308 non-null object
# Item Description    326308 non-null object
# Segment Target      326308 non-null object
# Services_dummy      326308 non-null int32
# dtypes: float64(3), int32(1), object(4)
# memory usage: 31.2+ MB

# %%
# check to ensure there are no null values
df_merged.isnull().sum()
# Out:
# Quantity              0
# Unit Price            0
# Total Price           0
# Supplier Name         0
# Item Name             0
# Item Description      0
# Segment Target        0
# Segment Target Cat    0
# dtype: int64

# %%
# check object statistics
df_merged.describe(include=['object']).transpose()
# Out:
#                      count  unique                        top   freq
# Supplier Name       326308   24430  Voyager Fleet Systems Inc  13756
# Item Name           326308  170898           Medical Supplies   2882
# Item Description    326308  207616           Medical Supplies   1361
# Segment Target      326308      26                Other Goods  49833
# Segment Target Cat  326308      26                         24  49833

# %%
# check float statisitcs
df_merged.describe().T
# Out:
#                 count          mean           std    min      25%       50%  \
# Quantity     326308.0  2.043375e+03  1.008739e+05  0.004      1.0       1.0
# Unit Price   326308.0  4.475731e+07  2.183321e+09  0.000   4100.0   60000.0
# Total Price  326308.0  4.517937e+07  2.183325e+09  1.000  35200.0  385195.5
#
#                    75%           max
# Quantity           7.0  2.000000e+07
# Unit Price   1018935.0  7.337038e+11
# Total Price  1488000.0  7.337038e+11

# %%
# one last check 
df_merged.sample(10)
# Out:
#         Quantity  Unit Price  Total Price  \
# 210246     400.0      3006.0    1202400.0
# 180501       3.0      3000.0       9000.0
# 215866       1.0  90000000.0   90000000.0
# 200951       2.0   8374000.0   16748000.0
# 290191       5.0    138054.0     690270.0
# 156271       1.0   1070000.0    1070000.0
# 80943       72.0      1195.0      86040.0
# 285273       1.0    311950.0     311950.0
# 99302        4.0      1500.0       6000.0
# 254494       1.0    939600.0     939600.0
#
#                                        Supplier Name  \
# 210246                              STAY SAFE SUPPLY
# 180501                     Prison Industry Authority
# 215866                 ORRICK HERRINGTON & SUTCLIFFE
# 200951                             Xerox Corporation
# 290191                                      Fastenal
# 156271                                   RIVCOMM LLC
# 80943   International Restaurant Equipment Co., Inc.
# 285273                           Future Data Systems
# 99302                        C-Tech Associates, Inc.
# 254494                           Sacramento Marriott
#
#                                       Item Name  \
# 210246        PAPER,COPY,20 LB,8-1/2" X 11",WHT
# 180501                             Set-in-place
# 215866           AM-07 Increase time and money.
# 200951      Equipment and software maintenance.
# 290191                HERBICIDE,ESPLANADE,200SC
# 156271  HAVIS KK12001 PRISONER TRANSPORT INSERT
# 80943       STEAMTABLE PANS ONE-FOURTH LIDS S/S
# 285273                                 keyboard
# 99302                                   coupler
# 254494                                  LODGING
#
#                                          Item Description  \
# 210246                  PAPER,COPY,20 LB,8-1/2" X 11",WHT
# 180501                                       Set-in-place
# 215866  This amendment extends the termination date by...
# 200951   Xerox printer equipment and software maintenance
# 290191                          HERBICIDE,ESPLANADE,200SC
# 156271            HAVIS KK12001 PRISONER TRANSPORT INSERT
# 80943                 STEAMTABLE PANS ONE-FOURTH LIDS S/S
# 285273                                           keyboard
# 99302                                             coupler
# 254494  TO PROVIDE LODGING FOR FIRE PERSONNEL ON SAND ...
#
#                                            Segment Target Segment Target Cat
# 210246                       Paper Materials and Products                  6
# 180501                       Industrial Cleaning Services                 14
# 215866                                     Other Services                 25
# 200951  Engineering and Research and Technology Based ...                  3
# 290191                                        Other Goods                 24
# 156271                                        Other Goods                 24
# 80943                                         Other Goods                 24
# 285273  Information Technology Broadcasting and Teleco...                  0
# 99302                           Furniture and Furnishings                 10
# 254494                                     Other Services                 25

# %%
# save cleaned data to be used for modelling (see included notebook Modelling)
df.to_csv('GoC Spend Data Cleaned (Quantity, Unit Price, Total Price, Supplier Name, Item Name, Item Description, UNSPSC Segment).csv', index=False)

# %% [markdown]
# <img src="data.PNG"
#      style="float: left; margin-right: 10px;" />

# %% [markdown]
# #### Modelling process can be found in the Modelling notebook
