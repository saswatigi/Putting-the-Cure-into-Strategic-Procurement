# %%
# Import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# The data set used was the [Goverment of California's 2012-2015 Purchase Orders ](https://data.ca.gov/dataset/purchase-order-data/resource/bb82edc5-9c78-44e2-8947-68ece26197c5) that are mapped the United Nations Standard Products & Services Code (UNSPSC). A Group Title column was added using excel (vlookup) for Goods and Services based on Segment Title.

# %%
# import dataset
df = pd.read_csv('GoC Spend Data.csv', encoding ='utf-8')

# %% [markdown]
# #### Initial Exploration

# %% [markdown]
# The dataset is made up of 344,504 rows (line items) with 33 columns comprised of 9 float and 23 object datatypes. The dataset has numerous columns specific to the Goverment of California (e.g. Acquisition Method), which for this capstone not relevant and therefor will not be further explored.

# %%
# peak into the dataset
df.head(5)
# Out:
#   Creation Date Purchase Date Fiscal Year       LPA Number  \
# 0     5/14/2014     5/14/2014   2013-2014              NaN
# 1      8/2/2013     7/18/2013   2013-2014              NaN
# 2    10/18/2013    10/18/2013   2013-2014  1-12-65-65-01-E
# 3      3/6/2014      3/6/2014   2013-2014              NaN
# 4     6/13/2014     5/22/2014   2013-2014              NaN
#
#   Purchase Order Number Requisition Number Acquisition Type  \
# 0              W0000828                NaN     NON-IT Goods
# 1            4500190668                NaN     NON-IT Goods
# 2              W0000487                NaN     NON-IT Goods
# 3              065D3010                NaN     NON-IT Goods
# 4           13-501-0338                NaN     NON-IT Goods
#
#   Sub-Acquisition Type    Acquisition Method Sub-Acquisition Method  ...  \
# 0                  NaN   Fair and Reasonable                    NaN  ...
# 1                  NaN  Informal Competitive                    NaN  ...
# 2                  NaN    Statewide Contract                    NaN  ...
# 3                  NaN        SB/DVBE Option                    NaN  ...
# 4                  NaN  Informal Competitive                    NaN  ...
#
#    Commodity Title       Class           Class Title      Family Family Title  \
# 0  Nurses uniforms  53102700.0              Uniforms  53100000.0     Clothing
# 1             Hats  53102500.0  Clothing accessories  53100000.0     Clothing
# 2    Adult diapers  53102300.0         Undergarments  53100000.0     Clothing
# 3  Police uniforms  53102700.0              Uniforms  53100000.0     Clothing
# 4    Adult diapers  53102300.0         Undergarments  53100000.0     Clothing
#
#       Segment                                   Segment Title Group Title  \
# 0  53000000.0  Apparel and Luggage and Personal Care Products       Goods
# 1  53000000.0  Apparel and Luggage and Personal Care Products       Goods
# 2  53000000.0  Apparel and Luggage and Personal Care Products       Goods
# 3  53000000.0  Apparel and Luggage and Personal Care Products       Goods
# 4  53000000.0  Apparel and Luggage and Personal Care Products       Goods
#
#                           Location  REMOVE AMERISOURCE
# 0  91789\n(34.019668, -117.856008)                 NaN
# 1                          98733\n                 NaN
# 2                              NaN                 NaN
# 3   92101\n(32.72112, -117.166986)                 NaN
# 4                              NaN                 NaN
#
# [5 rows x 33 columns]

# %%
# check dataset shape
df.shape
# Out:
# (344504, 33)

# %%
# inspect dataset make up
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344504 entries, 0 to 344503
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Creation Date            344504 non-null  object
#  1   Purchase Date            327083 non-null  object
#  2   Fiscal Year              344504 non-null  object
#  3   LPA Number               90897 non-null   object
#  4   Purchase Order Number    344504 non-null  object
#  5   Requisition Number       14366 non-null   object
#  6   Acquisition Type         344504 non-null  object
#  7   Sub-Acquisition Type     68334 non-null   object
#  8   Acquisition Method       344504 non-null  object
#  9   Sub-Acquisition Method   30883 non-null   object
#  10  Department Name          344504 non-null  object
#  11  Supplier Code            344468 non-null  float64
#  12  Supplier Name            344468 non-null  object
#  13  Supplier Qualifications  141745 non-null  object
#  14  Supplier Zip Code        274424 non-null  object
#  15  CalCard                  344504 non-null  object
#  16  Item Name                344473 non-null  object
#  17  Item Description         344305 non-null  object
#  18  Quantity                 344474 non-null  float64
#  19  Unit Price               344474 non-null  float64
#  20  Total Price              344474 non-null  float64
#  21  Classification Codes     343487 non-null  object
#  22  Normalized UNSPSC        343487 non-null  float64
#  23  Commodity Title          341211 non-null  object
#  24  Class                    341211 non-null  float64
#  25  Class Title              341211 non-null  object
#  26  Family                   341211 non-null  float64
#  27  Family Title             341211 non-null  object
#  28  Segment                  341211 non-null  float64
#  29  Segment Title            341211 non-null  object
#  30  Group Title              341211 non-null  object
#  31  Location                 274424 non-null  object
#  32  REMOVE AMERISOURCE       0 non-null       float64
# dtypes: float64(9), object(24)
# memory usage: 86.7+ MB

# %% [markdown]
# # drop all taxonomy titles
# drop_target_columns = ['Family Title','Class Title', 'Commodity Title', 'Group Title', 'Segment Title']
#
# for columns in drop_target_columns:
#     df = df.drop([columns], axis=1)

# %%
# explore object columns
df.describe(include=['object']).transpose()
# Out:
#                           count  unique  \
# Creation Date            344504    1015
# Purchase Date            327083    2266
# Fiscal Year              344504       3
# LPA Number                90897    1418
# Purchase Order Number    344504  196899
# Requisition Number        14366    5996
# Acquisition Type         344504       5
# Sub-Acquisition Type      68334      25
# Acquisition Method       344504      20
# Sub-Acquisition Method    30883      16
# Department Name          344504     111
# Supplier Name            344468   24728
# Supplier Qualifications  141745     278
# Supplier Zip Code        274424    3993
# CalCard                  344504       2
# Item Name                344473  179659
# Item Description         344305  218697
# Classification Codes     343487   45743
# Commodity Title          341211   13072
# Class Title              341211    2344
# Family Title             341211     411
# Segment Title            341211      56
# Group Title              341211       2
# Location                 274424    3993
#
#                                                                        top  \
# Creation Date                                                    6/27/2014
# Purchase Date                                                     7/1/2014
# Fiscal Year                                                      2013-2014
# LPA Number                                                      7-11-51-02
# Purchase Order Number                                           4500211314
# Requisition Number                                              REQ0008872
# Acquisition Type                                              NON-IT Goods
# Sub-Acquisition Type                                     Personal Services
# Acquisition Method                                    Informal Competitive
# Sub-Acquisition Method                                               Fleet
# Department Name              Corrections and Rehabilitation, Department of
# Supplier Name                                    Voyager Fleet Systems Inc
# Supplier Qualifications                                        CA-MB CA-SB
# Supplier Zip Code                                                    95691
# CalCard                                                                 NO
# Item Name                                                 Medical Supplies
# Item Description                                              confidential
# Classification Codes                                              15101506
# Commodity Title                                         Gasoline or Petrol
# Class Title                                      Petroleum and distillates
# Family Title             Office machines and their supplies and accesso...
# Segment Title            Information Technology Broadcasting and Teleco...
# Group Title                                                          Goods
# Location                                   95691\n(38.575311, -121.560401)
#
#                            freq
# Creation Date              1531
# Purchase Date              4433
# Fiscal Year              120158
# LPA Number                 9267
# Purchase Order Number       602
# Requisition Number          123
# Acquisition Type         213578
# Sub-Acquisition Type      16104
# Acquisition Method        82046
# Sub-Acquisition Method    14148
# Department Name           57533
# Supplier Name             13756
# Supplier Qualifications   53077
# Supplier Zip Code         11095
# CalCard                  339132
# Item Name                  2911
# Item Description           1637
# Classification Codes      12679
# Commodity Title           12776
# Class Title               14584
# Family Title              16478
# Segment Title             32679
# Group Title              254347
# Location                  11095

# %%
df.shape
# Out:
# (344504, 33)

# %% [markdown]
# Kept only relevant columns to reduce dataset set and computational requires for cleaning. While the model only incorporates Supplier Name, Item Name and Item Description as features and Segment as target, kept Quantity, Unit Price and Total price for future analysis and cleaning.

# %%
# only keep relevant columns going forward
df = df[['Quantity', 'Unit Price', 'Total Price', 'Supplier Name', 'Item Name', 'Item Description', 'Segment Title', 'Group Title']]

# %% [markdown]
# #### Cleaning Process

# %%
df
# Out:
#         Quantity  Unit Price  Total Price  \
# 0            1.0     3593.00      3593.00
# 1            1.0      995.04       995.04
# 2            1.0     2777.60      2777.60
# 3          100.0        4.22       422.00
# 4           60.0       24.00      1440.00
# ...          ...         ...          ...
# 344499       1.0     5784.95      5784.95
# 344500       1.0     1047.00      1047.00
# 344501       1.0     5237.45      5237.45
# 344502       1.0     6292.66      6292.66
# 344503      10.0      510.00      5100.00
#
#                                    Supplier Name  \
# 0                             A&M Uniforms, Inc.
# 1                              IBHP INCORPORATED
# 2       McKesson Medical - Surgical Minnesota Su
# 3                           SUCCOR INTERNATIONAL
# 4                                Edwards Medical
# ...                                          ...
# 344499                          Pressman's Pride
# 344500                          Capital Datacorp
# 344501                            AVANT PRINTING
# 344502              Technology Integration Group
# 344503           The Bode Technology Group, Inc.
#
#                                        Item Name  \
# 0                                       uniforms
# 1                                            hat
# 2                                  adult diapers
# 3                        Flashlight Pouch, Black
# 4                            Large Pullup Breifs
# ...                                          ...
# 344499                                       Ink
# 344500  Lansweeper Premium Subscription - 1 year
# 344501                            artwork frames
# 344502                      Dell Powervault 114X
# 344503                                lab supply
#
#                                 Item Description  \
# 0                                       uniforms
# 1                                            hat
# 2                                  adult diapers
# 3                              Condor # MA48-002
# 4                 Large Pullup Breifs - Covidien
# ...                                          ...
# 344499                                       Ink
# 344500  Lansweeper Premium Subscription - 1 year
# 344501                            artwork frames
# 344502                      Dell Powervault 114X
# 344503        Tray Pull-Straps/Desiccant Carrier
#
#                                          Segment Title Group Title
# 0       Apparel and Luggage and Personal Care Products       Goods
# 1       Apparel and Luggage and Personal Care Products       Goods
# 2       Apparel and Luggage and Personal Care Products       Goods
# 3       Apparel and Luggage and Personal Care Products       Goods
# 4       Apparel and Luggage and Personal Care Products       Goods
# ...                                                ...         ...
# 344499                                             NaN         NaN
# 344500                                             NaN         NaN
# 344501                                             NaN         NaN
# 344502                                             NaN         NaN
# 344503                                             NaN         NaN
#
# [344504 rows x 8 columns]

# %%
# drop rows that aren't categorized
df = df[df['Segment Title'].notna()]

# drop rows with negative or 0 prices
df = df.drop(df[df['Total Price'].astype(float) <= 0].index)

# drop suppliers listed as 'unknown'
df = df.drop(df[df['Supplier Name'] == 'Unknown'].index)

# drop rows with item description as 'confidential'
df = df.drop(df[df['Item Description'] == 'confidential'].index)

# drop rows with item name missing
df = df.drop(df[df['Item Name'].isna() == True].index)

# drop rows with item description missing
df = df.drop(df[df['Item Description'].isna() == True].index)

# drop rows with supplier name missing
df = df.drop(df[df['Supplier Name'].isna() == True].index)

# %%
# create and merge group title dummy, drop first and droup original group title column containing strings

#create group title dummy creating a binaray column with Services as 1 and Goods as 0
dummy_group_title = pd.get_dummies(df['Group Title'], drop_first = True)

# drop Group Title column as it is no longer needed
df = df.drop('Group Title', axis=1)

# merge group dummy to df
df = pd.merge(df,dummy_group_title,how='outer',left_index=True,right_index=True)

# %%
df
# Out:
#         Quantity  Unit Price  Total Price  \
# 0            1.0     3593.00      3593.00
# 1            1.0      995.04       995.04
# 2            1.0     2777.60      2777.60
# 3          100.0        4.22       422.00
# 4           60.0       24.00      1440.00
# ...          ...         ...          ...
# 341206    1408.0        0.95      1341.12
# 341207     160.0       24.51      3921.60
# 341208       1.0      180.00       180.00
# 341209   27000.0        1.20     32400.00
# 341210       1.0     2000.00      2000.00
#
#                                    Supplier Name                Item Name  \
# 0                             A&M Uniforms, Inc.                 uniforms
# 1                              IBHP INCORPORATED                      hat
# 2       McKesson Medical - Surgical Minnesota Su            adult diapers
# 3                           SUCCOR INTERNATIONAL  Flashlight Pouch, Black
# 4                                Edwards Medical      Large Pullup Breifs
# ...                                          ...                      ...
# 341206                     McGinty Sales Company         RMA Cheese Lunch
# 341207            Scofield Catering & Management         Fire Meal-Dinner
# 341208                  Class Act Alliance, Inc.              Interpreter
# 341209                     McGinty Sales Company    Box Lunch Meat/Cheese
# 341210                 Prison Industry Authority           Moving sercies
#
#                                          Item Description  \
# 0                                                uniforms
# 1                                                     hat
# 2                                           adult diapers
# 3                                       Condor # MA48-002
# 4                          Large Pullup Breifs - Covidien
# ...                                                   ...
# 341206                                   RMA Cheese Lunch
# 341207                                   Fire Meal Dinner
# 341208  Contractor will provide a Captioner for a tele...
# 341209                              Box Lunch Meat/Cheese
# 341210                                    moving services
#
#                                             Segment Title  Services
# 0          Apparel and Luggage and Personal Care Products         0
# 1          Apparel and Luggage and Personal Care Products         0
# 2          Apparel and Luggage and Personal Care Products         0
# 3          Apparel and Luggage and Personal Care Products         0
# 4          Apparel and Luggage and Personal Care Products         0
# ...                                                   ...       ...
# 341206  Travel and Food and Lodging and Entertainment ...         1
# 341207  Travel and Food and Lodging and Entertainment ...         1
# 341208  Travel and Food and Lodging and Entertainment ...         1
# 341209  Travel and Food and Lodging and Entertainment ...         1
# 341210  Travel and Food and Lodging and Entertainment ...         1
#
# [326308 rows x 8 columns]

# %%
df = df.rename(columns={'Segment Title': 'Segment Target'})

# %%
df
# Out:
#         Quantity  Unit Price  Total Price  \
# 0            1.0     3593.00      3593.00
# 1            1.0      995.04       995.04
# 2            1.0     2777.60      2777.60
# 3          100.0        4.22       422.00
# 4           60.0       24.00      1440.00
# ...          ...         ...          ...
# 341206    1408.0        0.95      1341.12
# 341207     160.0       24.51      3921.60
# 341208       1.0      180.00       180.00
# 341209   27000.0        1.20     32400.00
# 341210       1.0     2000.00      2000.00
#
#                                    Supplier Name                Item Name  \
# 0                             A&M Uniforms, Inc.                 uniforms
# 1                              IBHP INCORPORATED                      hat
# 2       McKesson Medical - Surgical Minnesota Su            adult diapers
# 3                           SUCCOR INTERNATIONAL  Flashlight Pouch, Black
# 4                                Edwards Medical      Large Pullup Breifs
# ...                                          ...                      ...
# 341206                     McGinty Sales Company         RMA Cheese Lunch
# 341207            Scofield Catering & Management         Fire Meal-Dinner
# 341208                  Class Act Alliance, Inc.              Interpreter
# 341209                     McGinty Sales Company    Box Lunch Meat/Cheese
# 341210                 Prison Industry Authority           Moving sercies
#
#                                          Item Description  \
# 0                                                uniforms
# 1                                                     hat
# 2                                           adult diapers
# 3                                       Condor # MA48-002
# 4                          Large Pullup Breifs - Covidien
# ...                                                   ...
# 341206                                   RMA Cheese Lunch
# 341207                                   Fire Meal Dinner
# 341208  Contractor will provide a Captioner for a tele...
# 341209                              Box Lunch Meat/Cheese
# 341210                                    moving services
#
#                                            Segment Target  Services
# 0          Apparel and Luggage and Personal Care Products         0
# 1          Apparel and Luggage and Personal Care Products         0
# 2          Apparel and Luggage and Personal Care Products         0
# 3          Apparel and Luggage and Personal Care Products         0
# 4          Apparel and Luggage and Personal Care Products         0
# ...                                                   ...       ...
# 341206  Travel and Food and Lodging and Entertainment ...         1
# 341207  Travel and Food and Lodging and Entertainment ...         1
# 341208  Travel and Food and Lodging and Entertainment ...         1
# 341209  Travel and Food and Lodging and Entertainment ...         1
# 341210  Travel and Food and Lodging and Entertainment ...         1
#
# [326308 rows x 8 columns]

# %% [markdown]
# #### Feature Engineering

# %% [markdown]
# Segment Target was reducted from 55 to 26 Segment categories. This was accomplished by the bottom 20% of categories by total rows neing grouped into either Other Goods or Other Services based on their commodity type. But first those categories needed to be found. A 47% reduction in spend categories resulting in only aggregating 7% of total spend. This was accomplished through the below.

# %%
# create a dataframe with Segment, Services Total Price grouped by Segment with sum and count (number of rows) of Total Price 
segment_target_df = pd.DataFrame(df.groupby(['Segment Target','Services'])['Total Price'].agg(['sum','count']).reset_index())

# sort by count
segment_target_df= segment_target_df.sort_values(by=('count'), ascending = False)

# create a column for cummaltive amount of rows
segment_target_df['cum_sum_count'] = segment_target_df['count'].cumsum()

# create a column for cummaltive percent of rows
segment_target_df['cum_perc_count'] = round(100*segment_target_df['cum_sum_count']/segment_target_df['count'].sum(),1)

# create a column for cummaltive sum of total spend
segment_target_df['cum_sum_sum'] = segment_target_df['sum'].cumsum()

# create a column for cummaltive percent of total spend
segment_target_df['cum_perc_sum'] = round(100*segment_target_df['cum_sum_sum']/segment_target_df['sum'].sum(),1)

# display 
segment_target_df
# Out:
#                                        Segment Target  Services           sum  \
# 26  Information Technology Broadcasting and Teleco...         0  1.928122e+09
# 9     756         324617            99.5  1.473182e+11          99.9
# 17    536         325153            99.6  1.473453e+11          99.9
# 48    501         325654            99.8  1.473537e+11         100.0
# 52    405         326059            99.9  1.473538e+11         100.0
# 42    249         326308           100.0  1.474239e+11         100.0

# %% [markdown]
# Using a nested where clause for segements with the grouping of bottom 20% of segments into either Other Goods or Other Services based on commmodity type

# %%
# using a nested where clause for segements with the grouping of bottom 20% of segments into either Other Goods or Other Services based on commmodity type
segment_target_df['Reduced Segment Target'] = np.where((segment_target_df['cum_perc_count']>80.5) & (segment_target_df['Services'] == 1), 'Other Services', \
                                                       np.where((segment_target_df['cum_perc_count']>80.5) & (segment_target_df['Services'] == 0), 'Other Goods', segment_target_df['Segment Target']))

# %%
segment_target_df
# Out:
#                                        Segment Target  Services           sum  \
# 26  Information Technology Broadcasting and Teleco...         0  1.928122e+09
# 19                 Food Beverage and Tobacco Products         0  4.660712e+08
# 39      Office Equipment and Accessories and Supplies         0  1.250900e+08
# 14  Engineering and Research and Technology Based ...         1  4.270134e+09
# 33     Medical Equipment and Accessories and Supplies         0  2.994211e+08
# 20  Fuels and Fuel Additives and Lubricants and An...         0  3.222314e+08
# 41                       Paper Materials and Products         0  1.336836e+08
# 5   Commercial and Military and Private Vehicles a...         0  1.097559e+09
# 11                    Education and Training Services         1  3.289646e+09
# 6   Defense and Law Enforcement and Security and S...         0  3.406194e+08
# 21                          Furniture and Furnishings         0  1.101441e+08
# 30  Management and Business Professionals and Admi...         1  5.137725e+09
# 22                                Healthcare Services         1  1.115454e+11
# 27  Laboratory and Measuring and Observing and Tes...         0  1.888920e+08
# 23                       Industrial Cleaning Services         1  3.373688e+08
# 51  Structures and Building and Construction and M...         0  5.450587e+08
# 44  Power Generation and Distribution Machinery an...         0  1.337334e+08
# 2   Building and Facility Construction and Mainten...         1  1.812050e+09
# 32  Material Handling and Conditioning and Storage...         0  9.343111e+07
# 54       Transportation and Storage and Mail Services         1  2.532134e+08
# 12  Electrical Systems and Lighting and Components...         0  1.309916e+08
# 31              Manufacturing Components and Supplies         0  4.262440e+07
# 43                Politics and Civic Affairs Services         1  3.223063e+09
# 47                                 Published Products         0  1.878465e+08
# 7   Distribution and Conditioning Systems and Equi...         0  8.651066e+07
# 0      Apparel and Luggage and Personal Care Products         0  8.968175e+07
# 4                     Cleaning Equipment and Supplies         0  8.954804e+07
# 37  Musical Instruments and Games and Toys and Art...         0  7.583501e+08
# 53                        Tools and General Machinery         0  3.623516e+07
# 8   Domestic Appliances and Supplies and Consumer ...         0  1.377086e+08
# 29  Live Plant and Animal Material and Accessories...         0  1.555479e+08
# 35  Mining and Well Drilling Machinery and Accesso...         0  1.093066e+08
# 24  Industrial Manufacturing and Processing Machin...         0  4.612714e+07
# 3   Chemicals including Bio Chemicals and Gas Mate...         0  9.588296e+07
# 10  Editorial and Design and Graphic and Fine Art ...         1  1.108618e+08
# 45  Printing and Photographic and Audio and Visual...         0  3.081301e+07
# 34  Mineral and Textile and Inedible Plant and Ani...         0  4.682150e+08
# 45   2167         302214            92.6  1.377607e+11          93.4
# 34   2141         304355            93.3  1.382289e+11          93.8
# 38   1920         306275            93.9  1.400328e+11          95.0
# 13   1876         308151            94.4  1.400589e+11          95.0
# 25   1870         310021            95.0  1.402400e+11          95.1
# 16   1831         311852            95.6  1.418076e+11          96.2
# 49   1633         313485            96.1  1.418305e+11          96.2
# 46   1488         314973            96.5  1.426268e+11          96.7
# 55   1454         316427            97.0  1.427025e+11          96.8
# 1    1334         317761            97.4  1.427759e+11          96.8
# 15   1231         318992            97.8  1.439717e+11          97.7
# 50   1144         320136            98.1  1.439835e+11          97.7
# 18   1008         321144            98.4  1.462069e+11          99.2
# 36    947         322091            98.7  1.464685e+11          99.4
# 28    913         323004            99.0  1.468299e+11          99.6
# 40    857         323861            99.3  1.472882e+11          99.9
# 9     756         324617            99.5  1.473182e+11          99.9
# 17    536         325153            99.6  1.473453e+11          99.9
# 48    501         325654            99.8  1.473537e+11         100.0
# 52    405         326059            99.9  1.473538e+11         100.0
# 42    249         326308           100.0  1.474239e+11         100.0
#
#                                Reduced Segment Target
# 26  Information Technology Broadcasting and Teleco...
# 19                 Food Beverage and Tobacco Products
# 39      Office Equipment and Accessories and Supplies
# 14  Engineering and Research and Technology Based ...
# 33     Medical Equipment and Accessories and Supplies
# 20  Fuels and Fuel Additives and Lubricants and An...
# 41                       Paper Materials and Products
# 5   Commercial and Military and Private Vehicles a...
# 11                    Education and Training Services
# 6   Defense and Law Enforcement and Security and S...
# 21                          Furniture and Furnishings
# 30  Management and Business Professionals and Admi...
# 22                                Healthcare Services
# 27  Laboratory and Measuring and Observing and Tes...
# 23                       Industrial Cleaning Services
# 51  Structures and Building and Construction and M...
# 44  Power Generation and Distribution Machinery an...
# 2   Building and Facility Construction and Mainten...
# 32  Material Handling and Conditioning and Storage...
# 54       Transportation and Storage and Mail Services
# 12  Electrical Systems and Lighting and Components...
# 31              Manufacturing Components and Supplies
# 43                Politics and Civic Affairs Services
# 47                                 Published Products
# 7                                         Other Goods
# 0                                         Other Goods
# 4                                         Other Goods
# 37                                        Other Goods
# 53                                        Other Goods
# 8                                         Other Goods
# 29                                        Other Goods
# 35                                        Other Goods
# 24                                        Other Goods
# 3                                         Other Goods
# 10                                     Other Services
# 45                                        Other Goods
# 34                                        Other Goods
# 38                                     Other Services
# 13                                        Other Goods
# 25                                     Other Services
# 16                                     Other Services
# 49                                        Other Goods
# 46                                     Other Services
# 55                                     Other Services
# 1                                         Other Goods
# 15                                     Other Services
# 50                                        Other Goods
# 18                                     Other Services
# 36                                     Other Services
# 28                                        Other Goods
# 40                                     Other Services
# 9                                         Other Goods
# 17                                        Other Goods
# 48                                        Other Goods
# 52                                        Other Goods
# 42                                     Other Services

# %%
# factorize reduced segement target for modelling 
segment_target_df['Segment Target Cat'] = segment_target_df['Reduced Segment Target'].factorize()[0]

segment_target_df['Segment Target Cat'] = segment_target_df['Segment Target Cat'].astype(str) 
#segment_target_df = segment_target_df.drop('Segment Target', axis=1)

#segment_target_df = segment_target_df.rename(columns={'Reduced Segment Target': 'Segment Target'})

# %%
df = pd.merge(df,segment_target_df[['Segment Target','Reduced Segment Target', 'Segment Target Cat']], how='left', left_on='Segment Target', right_on ='Segment Target')

# %% [markdown]
# Since the original dataset did not have goods and services, that column was dropped

# %%
# drop Goods and Services column
df = df.drop(['Services', 'Segment Target'], axis=1)

# %%
df = df.rename(columns={'Reduced Segment Target': 'Segment Target'})

# %% [markdown]
# #### Finalized Cleaned Dataset

# %% [markdown]
# Check to see if there are any nulls, the correct columns are present in the correct data type.
#
# The cleaned dataset has 326,208 rows with 8 columns, 3 float and 5 object.

# %%
# check info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 326308 entries, 0 to 326307
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Quantity            326308 non-null  float64
#  1   Unit Price          326308 non-null  float64
#  2   Total Price         326308 non-null  float64
#  3   Supplier Name       326308 non-null  object
#  4   Item Name           326308 non-null  object
#  5   Item Description    326308 non-null  object
#  6   Segment Target      326308 non-null  object
#  7   Segment Target Cat  326308 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 22.4+ MB

# %%
# check to ensure there are no null values
df.isnull().sum()
# Out:
# Quantity              0
# Unit Price            0
# Total Price           0
# Supplier Name         0
# Item Name             0
# Item Description      0
# Segment Target        0
# Segment Target Cat    0
# dtype: int64

# %%
# check object statistics
df.describe(include=['object']).transpose()
# Out:
#                      count  unique                        top   freq
# Supplier Name       326308   24430  Voyager Fleet Systems Inc  13756
# Item Name           326308  170898           Medical Supplies   2882
# Item Description    326308  207616           Medical Supplies   1361
# Segment Target      326308      26                Other Goods  49833
# Segment Target Cat  326308      26                         24  49833

# %%
# check float statisitcs
df.describe().T
# Out:
#                 count           mean           std    min    25%       50%  \
# Quantity     326308.0    2043.375498  1.008739e+05  0.004    1.0     1.000
# Unit Price   326308.0  447573.094654  2.183321e+07  0.000   41.0   600.000
# Total Price  326308.0  451793.696625  2.183325e+07  0.010  352.0  3851.955
#
#                   75%           max
# Quantity         7.00  2.000000e+07
# Unit Price   10189.35  7.337038e+09
# Total Price  14880.00  7.337038e+09

# %%
# one last check 
df.head()
# Out:
#    Quantity  Unit Price  Total Price  \
# 0       1.0     3593.00      3593.00
# 1       1.0      995.04       995.04
# 2       1.0     2777.60      2777.60
# 3     100.0        4.22       422.00
# 4      60.0       24.00      1440.00
#
#                               Supplier Name                Item Name  \
# 0                        A&M Uniforms, Inc.                 uniforms
# 1                         IBHP INCORPORATED                      hat
# 2  McKesson Medical - Surgical Minnesota Su            adult diapers
# 3                      SUCCOR INTERNATIONAL  Flashlight Pouch, Black
# 4                           Edwards Medical      Large Pullup Breifs
#
#                  Item Description Segment Target Segment Target Cat
# 0                        uniforms    Other Goods                 24
# 1                             hat    Other Goods                 24
# 2                   adult diapers    Other Goods                 24
# 3               Condor # MA48-002    Other Goods                 24
# 4  Large Pullup Breifs - Covidien    Other Goods                 24

# %%
# save cleaned data to be used for modelling (see included notebook Modelling)
df.to_csv('GoC Spend Data Cleaned (Quantity, Unit Price, Total Price, Supplier Name, Item Name, Item Description, UNSPSC Segment).csv', index=False)

# %% [markdown]
# #### Modelling process can be found in the Modelling notebook
